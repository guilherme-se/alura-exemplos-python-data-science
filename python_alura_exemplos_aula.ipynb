# %% [markdown]
# # <font color=green> PYTHON PARA DATA SCIENCE - PANDAS
# ---

# %% [markdown]
# # <font color=green> 1. INTRODUÇÃO AO PYTHON
# ---

# %% [markdown]
# # 1.1 Introdução

# %% [markdown]
# > Python é uma linguagem de programação de alto nível com suporte a múltiplos paradigmas de programação. É um projeto *open source* e desde seu surgimento, em 1991, vem se tornando uma das linguagens de programação interpretadas mais populares.
# >
# > Nos últimos anos Python desenvolveu uma comunidade ativa de processamento científico e análise de dados e vem se destacando como uma das linguagens mais relevantes quando o assundo é ciência de dados e machine learning, tanto no ambiente acadêmico como também no mercado.

# %% [markdown]
# # 1.2 Instalação e ambiente de desenvolvimento

# %% [markdown]
# ### Instalação Local
#
# ### https://www.python.org/downloads/
# ### ou
# ### https://www.anaconda.com/distribution/

# %% [markdown]
# ### Google Colaboratory
#
# ### https://colab.research.google.com

# %% [markdown]
# ### Verificando versão

# %%
# !python -V
# Out:
# Python 3.10.12

# %% [markdown]
# # 1.3 Trabalhando com dados

# %%
import pandas as pd

# %%
dataset = pd.read_csv('db.csv', sep = ';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# 0      False  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1      False  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2      False  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3       True  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4      False  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..       ...                                                ...        ...
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255    False  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256    False  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257    False  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
# [258 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8754408147734026174 = autoviz.get_registered_df('df_8754408147734026174')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8754408147734026174, *['Ano'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5084318837562914115 = autoviz.get_registered_df('df_5084318837562914115')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_5084318837562914115, *['Quilometragem'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3283468442300547251 = autoviz.get_registered_df('df_3283468442300547251')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3283468442300547251, *['Valor'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3103310216714228795 = autoviz.get_registered_df('df_3103310216714228795')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3103310216714228795, *['Ano'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1263239085111348060 = autoviz.get_registered_df('df_1263239085111348060')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_1263239085111348060, *['Quilometragem'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_9125266632441062421 = autoviz.get_registered_df('df_9125266632441062421')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_9125266632441062421, *['Valor'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4060009616604154785 = autoviz.get_registered_df('df_4060009616604154785')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_4060009616604154785, *['Zero_km'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_9177878392566758103 = autoviz.get_registered_df('df_9177878392566758103')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_9177878392566758103, *[[['Ano', 'Quilometragem'], ['Quilometragem', 'Valor']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7094152293462999915 = autoviz.get_registered_df('df_7094152293462999915')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_7094152293462999915, *['Ano', 'Zero_km'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7788454714928407605 = autoviz.get_registered_df('df_7788454714928407605')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_7788454714928407605, *['Quilometragem', 'Zero_km'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1795552351720279755 = autoviz.get_registered_df('df_1795552351720279755')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_1795552351720279755, *['Valor', 'Zero_km'], **{'inner': 'stick'})
# chart

# %%
dataset.dtypes
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
dataset[['Quilometragem', 'Valor']].describe()
# Out:
#        Quilometragem          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4519040184751921854 = autoviz.get_registered_df('df_4519040184751921854')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4519040184751921854, *['Quilometragem'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4519040184751921854 = autoviz.get_registered_df('df_4519040184751921854')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4519040184751921854, *['Valor'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4519040184751921854 = autoviz.get_registered_df('df_4519040184751921854')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_4519040184751921854, *['Quilometragem'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4519040184751921854 = autoviz.get_registered_df('df_4519040184751921854')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_4519040184751921854, *['Valor'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4519040184751921854 = autoviz.get_registered_df('df_4519040184751921854')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_4519040184751921854, *[[['Quilometragem', 'Valor']]], **{})
# chart

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# # <font color=green> 2. TRABALHANDO COM TUPLAS
# ---

# %% [markdown]
# # 2.1 Criando tuplas
#
# Tuplas são sequências imutáveis que são utilizadas para armazenar coleções de itens, geralmente heterogêneos. Podem ser construídas de várias formas:
# ```
# - Utilizando um par de parênteses: ( )
# - Utilizando uma vírgula à direita: x,
# - Utilizando um par de parênteses com itens separados por vírgulas: ( x, y, z )
# - Utilizando: tuple() ou tuple(iterador)
# ```

# %%
nome = 'guilherme'
idade = 17

(nome,idade)
# Out:
# ('guilherme', 17)

# %%
1,2,3
# Out:
# (1, 2, 3)

# %%
nome_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nome_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
type (nome_carros)
# Out:
# tuple

# %% [markdown]
# # 2.2 Seleções em tuplas

# %%
nome_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nome_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
nome_carros[0]
# Out:
# 'Jetta Variant'

# %%
nome_carros[2]
# Out:
# 'Crossfox'

# %%
nome_carros[1:3]
# Out:
# ('Passat', 'Crossfox')

# %%
nome_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))
nome_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))

# %%
nome_carros[-1][1]
# Out:
# 'Gol'

# %% [markdown]
# # 2.3 Iterando em tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
for carros in nomes_carros:
  print (carros)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DS5

# %% [markdown]
# ### Desempacotamento de tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
carro1, carro2, carro3, carro4 = nomes_carros

# %%
carro1
# Out:
# 'Jetta Variant'

# %%
carro2
# Out:
# 'Passat'

# %%
carro3
# Out:
# 'Crossfox'

# %%
carro4
# Out:
# 'DS5'

# %%
_, A, _, B = nomes_carros

# %%
A
# Out:
# 'Passat'

# %%
B
# Out:
# 'DS5'

# %%
_, C, *_ = nomes_carros

# %%
C
# Out:
# 'Passat'

# %% [markdown]
# ## *zip()*
#
# https://docs.python.org/3.6/library/functions.html#zip

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
list(zip(carros,valores))
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
for item in zip (carros, valores):
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)

# %%
for carro, valor in zip (carros, valores):
  print(carro, valor)
# Out:
# Jetta Variant 88078.64
# Passat 106161.94
# Crossfox 72832.16
# DS5 124549.07

# %%
for carro, valor in zip (carros, valores):
  if (valor > 100000):
    print(carro)
# Out:
# Passat
# DS5

# %% [markdown]
# # <font color=green> 3. TRABALHANDO COM DICIONÁRIOS
# ---

# %% [markdown]
# # 3.1 Criando dicionários
#
# Listas são coleções sequenciais, isto é, os itens destas sequências estão ordenados e utilizam índices (números inteiros) para acessar os valores.
#
# Os dicionários são coleções um pouco diferentes. São estruturas de dados que representam um tipo de mapeamento. Mapeamentos são coleções de associações entre pares de valores onde o primeiro elemento do par é conhecido como chave (*key*) e o segundo como valor (*value*).
#
# ```
# dicionario = {key_1: value_1, key_2: value_2, ..., key_n: value_n}
# ```
#
# https://docs.python.org/3.6/library/stdtypes.html#typesmapping

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros

# %%
valores = [88078.64, 106161.94, 72832.16]
valores

# %%
dados = {'Jetta Variant':88078.64, 'Passat':106161.94, 'Crossfox':72832.16}
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
type(dados)
# Out:
# dict

# %% [markdown]
# ### Criando dicionários com *zip()*

# %%
list(zip(carros,valores))
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
dados = dict(zip(carros,valores))
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'Crossfox': 72832.16,
#  'DS5': 124549.07}

# %% [markdown]
# # 3.2 Operações com dicionários

# %%
dados = {'Jetta Variant':88078.64, 'Passat':106161.94, 'Crossfox':72832.16}
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %% [markdown]
# ## *dict[ key ]*
#
# Retorna o valor correspondente à chave (*key*) no dicionário.

# %%
dados['Passat']
# Out:
# 106161.94

# %% [markdown]
# ## *key in dict*
#
# Retorna **True** se a chave (*key*) for encontrada no dicionário.

# %%
'Passat' in dados
# Out:
# True

# %%
'Fusca' in dados
# Out:
# False

# %%
'Fusca' not in dados
# Out:
# True

# %% [markdown]
# ## *len(dict)*
#
# Retorna o número de itens do dicionário.

# %%
len(dados)
# Out:
# 3

# %% [markdown]
# ## *dict[ key ] = value*
#
# Inclui um item ao dicionário.

# %%
dados['DS5'] = 12345.67

# %%
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'Crossfox': 72832.16,
#  'DS5': 12345.67}

# %% [markdown]
# ## *del dict[ key ]*
#
# Remove o item de chave (*key*) do dicionário.

# %%
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'Crossfox': 72832.16,
#  'DS5': 12345.67}

# %%
del dados['Crossfox']
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'DS5': 12345.67}

# %% [markdown]
# # 3.3 Métodos de dicionários

# %% [markdown]
# ## *dict.update()*
#
# Atualiza o dicionário.

# %%
dados.update({'Crossfox': 72839.96, 'Fusca': 30000})
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'DS5': 12345.67,
#  'Crossfox': 72839.96,
#  'Fusca': 30000}

# %% [markdown]
# ## *dict.copy()*
#
# Cria uma cópia do dicionário.

# %%
dadosCopy = dados.copy()

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72839.96}

# %%
del dadosCopy['DS5']

# %%
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'DS5': 12345.67,
#  'Crossfox': 72839.96,
#  'Fusca': 30000}

# %% [markdown]
# ## *dict.pop(key[, default ])*
#
# Se a chave for encontrada no dicionário, o item é removido e seu valor é retornado. Caso contrário, o valor especificado como *default* é retornado. Se o valor *default* não for fornecido e a chave não for encontrada no dicionário um erro será gerado.

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72839.96}

# %%
dadosCopy.pop('Passat','chave nao encontrada')
# Out:
# 'chave nao encontrada'

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72839.96}

# %% [markdown]
# ## *dict.clear()*
#
# Remove todos os itens do dicionário.

# %%
dadosCopy.clear()

# %%
dadosCopy
# Out:
# {}

# %% [markdown]
# # 3.4 Iterando em dicionários

# %% [markdown]
# ## *dict.keys()*
#
# Retorna uma lista contendo as chaves (*keys*) do dicionário.

# %%
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'DS5': 12345.67,
#  'Crossfox': 72839.96,
#  'Fusca': 30000}

# %%
dados.keys()

for key in dados.keys():
  print(dados[key])
# Out:
# 88078.64
# 106161.94
# 12345.67
# 72839.96
# 30000

# %% [markdown]
# ## *dict.values()*
#
# Retorna uma lista com todos os valores (*values*) do dicionário.

# %%
dados.values()
# Out:
# dict_values([88078.64, 106161.94, 12345.67, 72839.96, 30000])

# %% [markdown]
# ## *dict.items()*
#
# Retorna uma lista contendo uma tupla para cada par chave-valor (*key-value*) do dicionário.

# %%
dados.items()
# Out:
# dict_items([('Jetta Variant', 88078.64), ('Passat', 106161.94), ('DS5', 12345.67), ('Crossfox', 72839.96), ('Fusca', 30000)])

# %% [markdown]
# # <font color=green> 4. FUNÇÕES E PACOTES
# ---
#
# Funções são unidades de código reutilizáveis que realizam uma tarefa específica, podem receber alguma entrada e também podem retornar alguma resultado.

# %% [markdown]
# # 4.1 Built-in function
#
# A linguagem Python possui várias funções integradas que estão sempre acessíveis. Algumas já utilizamos em nosso treinamento: type(), print(), zip(), len(), set() etc.
#
# https://docs.python.org/3.6/library/functions.html

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
list(dados.values())
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
sum(dados.values())
# Out:
# 267072.74

# %% [markdown]
# # 4.2 Definindo funções sem e com parâmetros

# %% [markdown]
# ### Funções sem parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>():
#     <instruções>
# ```

# %%
def media():
  valor = (1+2+3) / 3
  print(valor)

# %%
media()
# Out:
# 2.0

# %% [markdown]
# ### Funções com parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
# ```

# %%
def media(number1,number2,number3):
  valor = (number1+number2+number3) / 3
  print(valor)

# %%
media(1,2,3)
# Out:
# 2.0

# %%
media(20,30,40)
# Out:
# 30.0

# %%
def media(lista):
  valor = sum(lista)/len(lista)
  print(valor)

# %%
media(1,2,3)
# Out:
# 2.0

# %% [markdown]
# # 4.3 Definindo funções que retornam valores

# %% [markdown]
# ### Funções que retornam um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return <resultado>
# ```

# %%
def media(lista):
  valor = sum(lista)/len(lista)
  return valor

# %%
resultado = media([1,2,3])

# %%
resultado
# Out:
# 2.0

# %% [markdown]
# ### Funções que retornam mais de um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return (<resultado_1>, <resultado_2>, ..., <resultado_n>)
# ```

# %%
def media(lista):
  valor = sum(lista)/len(lista)
  return (valor, len(lista))

# %%
resultado, numero_lista = media([1,2,3])

# %%
resultado
# Out:
# 2.0

# %%
numero_lista
# Out:
# 3

# %% [markdown]
# # <font color=green> 5. PANDAS BÁSICO
# ---
#
# **versão: 0.25.2**
#
# Pandas é uma ferramenta de manipulação de dados de alto nível, construída com base no pacote Numpy. O pacote pandas possui estruturas de dados bastante interessantes para manipulação de dados e por isso é muito utilizado por cientistas de dados.
#
#
# ## Estruturas de Dados
#
# ### Series
#
# Series são arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado. Os rótulos das linhas são chamados de **index**. A forma básica de criação de uma Series é a seguinte:
#
#
# ```
#     s = pd.Series(dados, index = index)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy ou uma constante.
#
# ### DataFrames
#
# DataFrame é uma estrutura de dados tabular bidimensional com rótulos nas linha e colunas. Como a Series, os DataFrames são capazes de armazenar qualquer tipo de dados.
#
#
# ```
#     df = pd.DataFrame(dados, index = index, columns = columns)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy, uma Series e outro DataFrame.
#
# **Documentação:** https://pandas.pydata.org/pandas-docs/version/0.25/

# %% [markdown]
# # 5.1 Estruturas de dados

# %%
import pandas as pd

# %% [markdown]
# ### Criando uma Series a partir de uma lista

# %%
carros = ['Jetta', 'Passat', 'Crossfox','Fusca']
carros
# Out:
# ['Jetta', 'Passat', 'Crossfox', 'Fusca']

# %%
pd.Series(carros)
# Out:
# 0       Jetta
# 1      Passat
# 2    Crossfox
# 3       Fusca
# dtype: object

# %% [markdown]
# ### Criando um DataFrame a partir de uma lista de dicionários

# %%
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]

# %%
dataset = pd.DataFrame(dados)
dataset
# dataset [['Nome','Motor','Ano','Quilometragem','Valor', 'Zero_km']]
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de um dicionário

# %%
dados2 = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'],
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
dataset = pd.DataFrame(dados2)
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de uma arquivo externo

# %%
dataset = pd.read_csv('db.csv', sep=';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# 0      False  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1      False  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2      False  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3       True  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4      False  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..       ...                                                ...        ...
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255    False  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256    False  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257    False  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
# [258 rows x 7 columns]

# %% [markdown]
# # 5.2 Seleções com DataFrames

# %% [markdown]
# ### Selecionando colunas

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset[['Valor']]
# Out:
#          Valor
# 0     88078.64
# 1    106161.94
# 2     72832.16
# 3    124549.07
# 4     92612.10
# ..         ...
# 253   51759.58
# 254   51667.06
# 255   68934.03
# 256  122110.90
# 257   90381.47
#
# [258 rows x 1 columns]

# %%
dataset['Valor']
# Out:
# 0       88078.64
# 1      106161.94
# 2       72832.16
# 3      124549.07
# 4       92612.10
#          ...
# 253     51759.58
# 254     51667.06
# 255     68934.03
# 256    122110.90
# 257     90381.47
# Name: Valor, Length: 258, dtype: float64

# %% [markdown]
# ### Selecionando linhas - [ i : j ]
#
# <font color=red>**Observação:**</font> A indexação tem origem no zero e nos fatiamentos (*slices*) a linha com índice i é **incluída** e a linha com índice j **não é incluída** no resultado.

# %%
dataset[0:4]
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1         Passat     Motor Diesel  1991         5712.0    False
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False
# 3            DS5  Motor 2.4 Turbo  2019            NaN     True
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %% [markdown]
# ### Utilizando .loc para seleções
#
# <font color=red>**Observação:**</font> Seleciona um grupo de linhas e colunas segundo os rótulos ou uma matriz booleana.

# %%
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# 0      False  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1      False  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2      False  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3       True  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4      False  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..       ...                                                ...        ...
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255    False  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256    False  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257    False  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
# [258 rows x 7 columns]

# %%
dataset.loc[['DS5']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-f47d8bd19c3c> in <cell line: 1>()
# ----> 1 dataset.loc[['DS5']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1299                     raise ValueError("Cannot index with multidimensional key")
#    1300
# -> 1301                 return self._getitem_iterable(key, axis=axis)
#    1302
#    1303             # nested tuple slicing
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1237
#    1238         # A collection of keys
# -> 1239         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240         return self.obj._reindex_with_indexers(
#    1241             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1430         axis_name = self.obj._get_axis_name(axis)
#    1431
# -> 1432         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1433
#    1434         return keyarr, indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6128                 if use_interval_msg:
#    6129                     key = list(key)
# -> 6130                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['DS5'], dtype='object')] are in the [index]"

# %% [markdown]
# ### Utilizando .iloc para seleções
#
# <font color=red>**Observação:**</font> Seleciona com base nos índices, ou seja, se baseia na posição das informações.

# %%
dataset.iloc[[1]]
# Out:
#      Nome         Motor   Ano  Quilometragem  Zero_km  \
# 1  Passat  Motor Diesel  1991         5712.0    False
#
#                                           Acessórios      Valor
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94

# %%
dataset.iloc[1:4]
# Out:
#        Nome            Motor   Ano  Quilometragem  Zero_km  \
# 1    Passat     Motor Diesel  1991         5712.0    False
# 2  Crossfox  Motor Diesel V8  1990        37123.0    False
# 3       DS5  Motor 2.4 Turbo  2019            NaN     True
#
#                                           Acessórios      Valor
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
dataset.iloc[1:4,[0,2,6]]
# Out:
#        Nome   Ano      Valor
# 1    Passat  1991  106161.94
# 2  Crossfox  1990   72832.16
# 3       DS5  2019  124549.07

# %% [markdown]
# # 5.3 Queries com DataFrames

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.Motor
# Out:
# 0            Motor 4.0 Turbo
# 1               Motor Diesel
# 2            Motor Diesel V8
# 3            Motor 2.4 Turbo
# 4            Motor 2.4 Turbo
#                ...
# 253                 Motor V8
# 254                 Motor V8
# 255    Motor 5.0 V8 Bi-Turbo
# 256             Motor Diesel
# 257          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
select = dataset.Motor == 'Motor Diesel'

# %%
select
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 253    False
# 254    False
# 255    False
# 256     True
# 257    False
# Name: Motor, Length: 258, dtype: bool

# %%
dataset[select]
# Out:
#                       Nome         Motor   Ano  Quilometragem  Zero_km  \
# 1                   Passat  Motor Diesel  1991         5712.0    False
# 23   Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# 60                 Sorento  Motor Diesel  2019            NaN     True
# 62        New Fiesta Hatch  Motor Diesel  2017       118895.0    False
# 69          Kangoo Express  Motor Diesel  2007        29132.0    False
# 74                     Fit  Motor Diesel  2013        44329.0    False
# 78             Cielo Hatch  Motor Diesel  2019            NaN     True
# 86                  Symbol  Motor Diesel  2016       117714.0    False
# 89                A4 Sedan  Motor Diesel  2002        30511.0    False
# 111               A4 Avant  Motor Diesel  2014        17357.0    False
# 119          Silver Shadow  Motor Diesel  2015        99052.0    False
# 124                  Camry  Motor Diesel  2019            NaN     True
# 145                   Clio  Motor Diesel  1990        66437.0    False
# 148       Série 3 M3 Coupé  Motor Diesel  2013        19896.0    False
# 149    Gallardo LP 560 – 4  Motor Diesel  2000       113045.0    False
# 157          Chana Utility  Motor Diesel  2009        52034.0    False
# 173            TT Roadster  Motor Diesel  1998       107392.0    False
# 189    Aston Martin Virage  Motor Diesel  2019            NaN     True
# 208                Sandero  Motor Diesel  2015        34783.0    False
# 210                    XKR  Motor Diesel  1996        85127.0    False
# 211                     X5  Motor Diesel  2002        13606.0    False
# 226           Dodge Dakota  Motor Diesel  1993        71544.0    False
# 233                 i30 CW  Motor Diesel  2015         8497.0    False
# 237           Série 7 Sedã  Motor Diesel  2019            NaN     True
# 240                    V60  Motor Diesel  2004        91840.0    False
# 256       Aston Martin DB5  Motor Diesel  1996         7685.0    False
#
#                                             Acessórios      Valor
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 23   ['Controle de estabilidade', 'Painel digital',...  125684.65
# 60   ['Sensor de chuva', 'Câmera de estacionamento'...   81399.35
# 62   ['Sensor de estacionamento', 'Travas elétricas...   66007.16
# 69   ['Bancos de couro', 'Câmbio automático', 'Pilo...  146716.91
# 74   ['Freios ABS', 'Câmera de estacionamento', 'Câ...   77836.23
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 86   ['4 X 4', 'Piloto automático', 'Sensor crepusc...  133030.60
# 89   ['Câmera de estacionamento', '4 X 4', 'Travas ...   96369.04
# 111  ['Teto panorâmico', '4 X 4', 'Bancos de couro'...  138946.88
# 119  ['4 X 4', 'Central multimídia', 'Ar condiciona...  143568.22
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 145  ['4 X 4', 'Câmbio automático', 'Freios ABS', '...  111130.33
# 148  ['Bancos de couro', 'Sensor de chuva', 'Ar con...   69219.89
# 149  ['Freios ABS', 'Teto panorâmico', 'Central mul...  144118.91
# 157  ['Ar condicionado', 'Sensor de estacionamento'...  132662.32
# 173  ['Ar condicionado', 'Sensor de estacionamento'...   85311.40
# 189  ['Travas elétricas', 'Controle de tração', 'Câ...   97290.18
# 208  ['Piloto automático', 'Teto panorâmico', 'Câmb...  112350.61
# 210  ['Controle de tração', 'Ar condicionado', 'Tra...   54263.16
# 211  ['Controle de tração', 'Piloto automático', 'T...   62041.32
# 226  ['Controle de tração', 'Sensor de estacionamen...  141083.35
# 233  ['Sensor de chuva', 'Vidros elétricos', 'Contr...   73311.75
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...   67539.79
# 240  ['Rodas de liga', 'Sensor crepuscular', 'Ar co...  114728.74
# 256  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90

# %%
dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km == True)]
# Out:
#                     Nome         Motor   Ano  Quilometragem  Zero_km  \
# 60               Sorento  Motor Diesel  2019            NaN     True
# 78           Cielo Hatch  Motor Diesel  2019            NaN     True
# 124                Camry  Motor Diesel  2019            NaN     True
# 189  Aston Martin Virage  Motor Diesel  2019            NaN     True
# 237         Série 7 Sedã  Motor Diesel  2019            NaN     True
#
#                                             Acessórios      Valor
# 60   ['Sensor de chuva', 'Câmera de estacionamento'...   81399.35
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 189  ['Travas elétricas', 'Controle de tração', 'Câ...   97290.18
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...   67539.79

# %% [markdown]
# ### Utilizando o método query

# %%
dataset.query('Motor == "Motor Diesel" and Zero_km ==True')
# Out:
#                     Nome         Motor   Ano  Quilometragem  Zero_km  \
# 60               Sorento  Motor Diesel  2019            NaN     True
# 78           Cielo Hatch  Motor Diesel  2019            NaN     True
# 124                Camry  Motor Diesel  2019            NaN     True
# 189  Aston Martin Virage  Motor Diesel  2019            NaN     True
# 237         Série 7 Sedã  Motor Diesel  2019            NaN     True
#
#                                             Acessórios      Valor
# 60   ['Sensor de chuva', 'Câmera de estacionamento'...   81399.35
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 189  ['Travas elétricas', 'Controle de tração', 'Câ...   97290.18
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...   67539.79

# %% [markdown]
# # 5.4 Iterando com DataFrames

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
for index, row in dataset.iterrows():
  if(2023 - row['Ano'] != 0):
    dataset.loc[index, 'Km_media'] = row['Quilometragem'] / (2023-row['Ano'])
  else:
    dataset.loc[index, 'Km_media'] = 0

dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor  \
# 0      False  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1      False  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2      False  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3       True  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4      False  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..       ...                                                ...        ...
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255    False  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256    False  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257    False  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
#         Km_media
# 0    2220.500000
# 1     178.500000
# 2    1124.939394
# 3            NaN
# 4    1515.117647
# ..           ...
# 253  3056.111111
# 254   936.906250
# 255  2506.523810
# 256   284.629630
# 257  1618.967742
#
# [258 rows x 8 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
#  7   Km_media       197 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(3)
# memory usage: 14.5+ KB

# %% [markdown]
# # 5.5 Tratamento de dados

# %%
dataset.Quilometragem.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
dataset[dataset.Quilometragem.isna()]
# Out:
#                      Nome            Motor   Ano  Quilometragem  Zero_km  \
# 3                     DS5  Motor 2.4 Turbo  2019            NaN     True
# 6                      A5  Motor 4.0 Turbo  2019            NaN     True
# 13                     J5         Motor V6  2019            NaN     True
# 17                     A3     Motor 1.0 8v  2019            NaN     True
# 21              Série 1 M         Motor V8  2019            NaN     True
# ..                    ...              ...   ...            ...      ...
# 238  Lamborghini Reventón  Motor 4.0 Turbo  2019            NaN     True
# 242            Benni Mini         Motor V8  2019            NaN     True
# 243                   Uno  Motor Diesel V6  2019            NaN     True
# 245              Santa Fe    Motor 3.0 32v  2019            NaN     True
# 248                  XC60  Motor 4.0 Turbo  2019            NaN     True
#
#                                             Acessórios      Valor  Km_media
# 3    ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07       NaN
# 6    ['Câmbio automático', 'Câmera de estacionament...   56445.20       NaN
# 13   ['Sensor crepuscular', 'Painel digital', 'Roda...   53183.38       NaN
# 17   ['4 X 4', 'Piloto automático', 'Central multim...   88552.39       NaN
# 21   ['Controle de estabilidade', 'Central multimíd...   94564.40       NaN
# ..                                                 ...        ...       ...
# 238  ['Controle de tração', 'Ar condicionado', 'Cen...   67664.86       NaN
# 242  ['Sensor crepuscular', 'Câmbio automático', 'C...  126247.84       NaN
# 243  ['Central multimídia', 'Sensor crepuscular', '...  128852.21       NaN
# 245  ['Travas elétricas', 'Ar condicionado', '4 X 4...  129415.33       NaN
# 248  ['Painel digital', 'Piloto automático', 'Centr...   77675.79       NaN
#
# [61 rows x 8 columns]

# %%
dataset.fillna(0,inplace=True)

# %%
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            0.0
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor  \
# 0      False  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1      False  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2      False  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3       True  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4      False  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..       ...                                                ...        ...
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255    False  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256    False  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257    False  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
#         Km_media
# 0    2220.500000
# 1     178.500000
# 2    1124.939394
# 3       0.000000
# 4    1515.117647
# ..           ...
# 253  3056.111111
# 254   936.906250
# 255  2506.523810
# 256   284.629630
# 257  1618.967742
#
# [258 rows x 8 columns]

# %%
dataset.query("Zero_km == True")
# Out:
#                      Nome            Motor   Ano  Quilometragem  Zero_km  \
# 3                     DS5  Motor 2.4 Turbo  2019            0.0     True
# 6                      A5  Motor 4.0 Turbo  2019            0.0     True
# 13                     J5         Motor V6  2019            0.0     True
# 17                     A3     Motor 1.0 8v  2019            0.0     True
# 21              Série 1 M         Motor V8  2019            0.0     True
# ..                    ...              ...   ...            ...      ...
# 238  Lamborghini Reventón  Motor 4.0 Turbo  2019            0.0     True
# 242            Benni Mini         Motor V8  2019            0.0     True
# 243                   Uno  Motor Diesel V6  2019            0.0     True
# 245              Santa Fe    Motor 3.0 32v  2019            0.0     True
# 248                  XC60  Motor 4.0 Turbo  2019            0.0     True
#
#                                             Acessórios      Valor  Km_media
# 3    ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07       0.0
# 6    ['Câmbio automático', 'Câmera de estacionament...   56445.20       0.0
# 13   ['Sensor crepuscular', 'Painel digital', 'Roda...   53183.38       0.0
# 17   ['4 X 4', 'Piloto automático', 'Central multim...   88552.39       0.0
# 21   ['Controle de estabilidade', 'Central multimíd...   94564.40       0.0
# ..                                                 ...        ...       ...
# 238  ['Controle de tração', 'Ar condicionado', 'Cen...   67664.86       0.0
# 242  ['Sensor crepuscular', 'Câmbio automático', 'C...  126247.84       0.0
# 243  ['Central multimídia', 'Sensor crepuscular', '...  128852.21       0.0
# 245  ['Travas elétricas', 'Ar condicionado', '4 X 4...  129415.33       0.0
# 248  ['Painel digital', 'Piloto automático', 'Centr...   77675.79       0.0
#
# [61 rows x 8 columns]
